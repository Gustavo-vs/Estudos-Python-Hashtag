# %% [markdown]
# # Comparadores

# %% [markdown]
# == igual
# ('==' é diferente de '=': o == é usado para  uma comparação se aquilo é igual a outra coisa e = significa recebe ou seja "x = 15" aqui estou dizendo que a variavel x tem o valor de 15 )
#
# != diferente
# >  maior que (>= maior ou igual)
# <  menor que (<= menor ou igual)
# in texto que existe dentro de outro texto
# not verifica o contrario da comparação
#
# OBS: Se em alguma condição você não quiser fazer nada, você pode  simplesmente escrever: pass

# %%
faturamento_loja_1 = 2500
faturamento_loja_2 = 2200
email = "guh@gmail.com" #email errado para ver o retorno do if not no programa

print('Programa 1')

if faturamento_loja_1 == faturamento_loja_2:
    print('Os faturamentos são iguais')
else:
    print('Os faturamentos são diferentes')
# Out:
# Programa 1
# Os faturamentos são diferentes

# %%
print('Programa 2')
if email != 'guh@gmail.com':
    print("Esse não é o e-mail do Gustavo")    
else:
    print("Esse é o e-mail do Gustavo")
# Out:
# Programa 2
# Esse é o e-mail do Gustavo

# %%
print("Programa 3")

email_usuario = input("Insira seu e-mail")
if not '@' in email_usuario:
    print("Email inválido")
else:
    print("Email válido")
# Out:
# Programa 3
# Email válido
